# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier

# %%
data= pd.read_csv("Japan_life_expectancy.csv")

# %%
data.head()
# Out:
#   Prefecture  Life_expectancy  Physician  Junior_col  University  Public_Hosp  \
# 0      Aichi            84.65      224.4        13.6        23.7         13.7
# 1      Akita            83.79      242.6        11.3        11.9         34.0
# 2     Aomori            82.80      212.5        11.4        11.8         42.9
# 3      Chiba            84.48      205.8        14.7        24.9         16.1
# 4      Ehime            84.24      276.7        14.2        18.0         17.4
#
#    Pshic_hosp  Beds_psic  Nurses  Avg_hours  ...  Park  Forest  \
# 0         0.5      164.3   845.4      171.5  ...  17.2    42.1
# 1         1.7      404.6  1105.5      173.0  ...  10.6    70.3
# 2         1.4      348.7  1108.8      174.5  ...  11.8    63.6
# 3         0.5      195.8   749.1      173.5  ...   5.5    30.1
# 4         1.0      329.7  1277.5      178.0  ...   7.2    70.5
#
#    Income_per capita  Density_pop  Hospitals    Beds  Ambulances  Health_exp  \
# ...

# %%
data.shape
# Out:
# (47, 23)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Prefecture         47 non-null     object
#  1   Life_expectancy    47 non-null     float64
#  2   Physician          47 non-null     float64
#  3   Junior_col         47 non-null     float64
#  4   University         47 non-null     float64
#  5   Public_Hosp        47 non-null     float64
#  6   Pshic_hosp         47 non-null     float64
#  7   Beds_psic          47 non-null     float64
#  8   Nurses             47 non-null     float64
#  9   Avg_hours          47 non-null     float64
#  10  Salary             47 non-null     float64
#  11  Elementary_school  47 non-null     float64
#  12  Sport_fac          47 non-null     float64
#  13  Park               47 non-null     float64
#  14  Forest             47 non-null     float64
# ...

# %%
data.drop(['Prefecture'],axis=1)
# Out:
#     Life_expectancy  Physician  Junior_col  University  Public_Hosp  \
# 0             84.65      224.4        13.6        23.7         13.7
# 1             83.79      242.6        11.3        11.9         34.0
# 2             82.80      212.5        11.4        11.8         42.9
# 3             84.48      205.8        14.7        24.9         16.1
# 4             84.24      276.7        14.2        18.0         17.4
# 5             84.91      257.9        12.9        18.8         22.8
# 6             84.54      309.9        14.2        20.4          8.9
# 7             83.71      205.7        11.6        13.1         20.6
# 8             84.71      224.5        13.4        18.5         24.7
# 9             84.16      233.8        14.7        17.5         16.5
# 10            85.06      267.1        16.1        23.1         14.1
# 11            84.00      251.3        14.1        14.4         21.1
# 12            84.81      266.1        13.7        24.5         16.6
# ...

# %%
data['Life_expectancy'] = data['Life_expectancy'].astype(int)

# %%
data['Welfare_exp'] = data['Welfare_exp'].astype(int)

# %%
display(data.dtypes)
# Out:
# Prefecture            object
# Life_expectancy        int64
# Physician            float64
# Junior_col           float64
# University           float64
# Public_Hosp          float64
# Pshic_hosp           float64
# Beds_psic            float64
# Nurses               float64
# Avg_hours            float64
# Salary               float64
# Elementary_school    float64
# Sport_fac            float64
# Park                 float64
# Forest               float64
# Income_per capita    float64
# Density_pop          float64
# Hospitals            float64
# Beds                 float64
# Ambulances           float64
# Health_exp           float64
# Educ_exp             float64
# Welfare_exp            int64
# dtype: object

# %%
life_expectancy= data[["Life_expectancy"]]
welfare_exp= data[["Welfare_exp"]]

# %%
x_train,x_test,y_train,y_test=train_test_split(life_expectancy,welfare_exp,test_size=1/3,random_state=0)

# %%
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (31, 1) (16, 1) (31, 1) (16, 1)

# %%
lin= LinearRegression()

# %%
lin.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(lin.intercept_)
# Out:
# [-26.83870968]

# %%
print(lin.coef_)
# Out:
# [[0.5]]

# %%
pred=lin.predict(x_test)

# %%
print(pred)
# Out:
# [[15.16129032]
#  [15.16129032]
#  [15.66129032]
#  [15.16129032]
#  [15.16129032]
#  [15.16129032]
#  [15.16129032]
#  [15.16129032]
#  [15.16129032]
#  [15.66129032]
#  [15.66129032]
#  [15.16129032]
#  [15.16129032]
#  [15.16129032]
#  [14.16129032]
#  [15.16129032]]

# %%
from sklearn import metrics

# %%
error=np.sqrt(metrics.mean_squared_error(y_test,pred))

# %%
print(f"THE ACCURACY IS ={abs(error-100)}")
# Out:
# THE ACCURACY IS =97.22149914746944
